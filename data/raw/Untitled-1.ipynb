# %%
import json

with open("../data/raw/shl_catalog.json", "r", encoding="utf-8") as f:
    data = json.load(f)

print("Number of assessments:", len(data))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import json
#       2
# ----> 3 with open("../data/raw/shl_catalog.json", "r", encoding="utf-8") as f:
#       4     data = json.load(f)
#       5
#       6 print("Number of assessments:", len(data))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/raw/shl_catalog.json'
