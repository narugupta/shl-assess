# %%
import pandas as pd

normalized_df = df.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2
# ----> 3 normalized_df = df.copy()
#
# NameError: name 'df' is not defined
